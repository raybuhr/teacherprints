# %%
import copy
import pandas as pd
import numpy as np
# Out:
# /Users/annacjacobson/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
def rttm_to_utterance_indexed_speaker_activity(df, outfile=None):
    """ Given an RTTM input file, generate a dataframe structured
        to support a visualization of type 'Speaker Activity' and optionally
        export to a csv located at {outfile}

        df = Pandas DataFrame containing a standard .rttm file
        outfile = destination for exported CSV (path, filename, extension)
    """

    # Check whether an outfile has been defined
    if outfile is not None:
        export = True

    # Drop the columns we don't care about from a base RTTM
    vizframe = copy.deepcopy(df) \
        .drop(
        columns=[
            'task',
            'inputFile',
            'one',
            'NA_1',
            'NA_2',
            'NA_3',
            'NA_4'])

    # Rename columns for our viz's purposes
    vizframe = vizframe.rename(columns={
        'start': 'START',
        'duration': 'DUR',
        'class': 'LABEL'
    })

    # Remap the model classes for this viz's purposes
    vizframe['LABEL'] = vizframe['LABEL'].map({
        'KCHI': 'CHILD',
        'CHI': 'CHILD',
        'FEM': 'ADULT',
        'MAL': 'ADULT'
    })

    # Filter the dataframe to just the 'clean' (non-'SPEECH') classes
    vizframe = vizframe[vizframe['LABEL'].isin(['CHILD', 'ADULT'])]
    vizframe['LABEL_NUM'] = vizframe['LABEL'] \
        .apply(lambda x: 1 if x == 'CHILD'
               else (-1 if x == 'ADULT' else NaN))
    vizframe['DUR_TRANS'] = vizframe['LABEL_NUM'] * vizframe['DUR']
    vizframe['COUNT'] = 1

    if export:
        vizframe.to_csv(outfile)

    return vizframe

# %%
def df_from_rttm(rttm):
    """ Given an RTTM file, parses it into a Pandas DataFrame.
    """
    df = pd.read_csv(rttm,
                     sep=' ',
                     names=['task','inputFile','one','start','duration',
                     'NA_1','NA_2','class','NA_3', 'NA_4'])
    return df

# %%
def get_latest_timestamp_needed(input_df):
    """ Given an RTTM-derived dataframe,
        extract the last timestamp we'll need
        as a scalar
    """
    last_row = input_df[input_df['start']==input_df['start'].max()][['start', 'duration']]
    last_row.reset_index(drop=True, inplace=True)
    latest_timestamp = last_row.at[0,'start'] + last_row.at[0,'duration']
    return round(latest_timestamp, 1)

# %%
ny_7759 = df_from_rttm('./TestData/eNY-7759.rttm')
ny_7759
# Out:
#         task inputFile  one    start  duration  NA_1  NA_2   class  NA_3  NA_4
# 0    SPEAKER  eNY-7759    1    6.038     5.191   NaN   NaN  SPEECH   NaN   NaN
# 1    SPEAKER  eNY-7759    1    6.198     0.813   NaN   NaN    KCHI   NaN   NaN
# 2    SPEAKER  eNY-7759    1    7.773     0.145   NaN   NaN    KCHI   NaN   NaN
# 3    SPEAKER  eNY-7759    1    9.560     0.380   NaN   NaN     MAL   NaN   NaN
# 4    SPEAKER  eNY-7759    1   10.694     0.240   NaN   NaN    KCHI   NaN   NaN
# ..       ...       ...  ...      ...       ...   ...   ...     ...   ...   ...
# 143  SPEAKER  eNY-7759    1  235.567     3.714   NaN   NaN     FEM   NaN   NaN
# 144  SPEAKER  eNY-7759    1  238.321     0.120   NaN   NaN     MAL   NaN   NaN
# 145  SPEAKER  eNY-7759    1  238.641     0.125   NaN   NaN     MAL   NaN   NaN
# 146  SPEAKER  eNY-7759    1  238.888     0.351   NaN   NaN    KCHI   NaN   NaN
# 147  SPEAKER  eNY-7759    1  239.007     0.140   NaN   NaN     CHI   NaN   NaN
#
# [148 rows x 10 columns]

# %%
# We need times to be in milliseconds
# ny_7759[['start', 'duration']] = ny_7759[['start', 'duration']]*1000

# %%
# This is to make our lives easier later
ny_7759_bak = copy.deepcopy(ny_7759)
# ny_7759 = copy.deepcopy(ny_7759_bak)

# %%
def build_second_range(start, duration, value='', valname='value', verbose=False):
    """ Given a start time, and end time, and a value,
        create a dataframe with a timedelta index containing
        that value for the range between the endpoints
    """
    
    # Turn the endpoints into a second-denominated target
    low_end = pd.to_timedelta(round(start, 1), unit='milliseconds')
    span = pd.to_timedelta(round(duration, 1), unit='milliseconds')
    
    if verbose:
        print(f"Low end: {low_end}\nDuration: {span}\n")
    
    # Create a range between them
    rng = pd.timedelta_range(low_end, low_end+span, freq='100L')

    # Turn that series into a DataFrame and rename the index for clarity
    df = pd.Series(value, index=rng).to_frame(name=valname)
    df.index.name='seconds'
    if verbose:
        print(df.head(3))
    return df

# %%
build_second_range(0, 3000, np.nan,'base', verbose=True)
# Out:
# Low end: 0 days 00:00:00
# Duration: 0 days 00:00:03
#
#                  base
# seconds
# 00:00:00          NaN
# 00:00:00.100000   NaN
# 00:00:00.200000   NaN
#                  base
# seconds
# 00:00:00          NaN
# 00:00:00.100000   NaN
# 00:00:00.200000   NaN
# 00:00:00.300000   NaN
# 00:00:00.400000   NaN
# 00:00:00.500000   NaN
# 00:00:00.600000   NaN
# 00:00:00.700000   NaN
# 00:00:00.800000   NaN
# 00:00:00.900000   NaN
# 00:00:01          NaN
# 00:00:01.100000   NaN
# 00:00:01.200000   NaN
# 00:00:01.300000   NaN
# 00:00:01.400000   NaN
# 00:00:01.500000   NaN
# 00:00:01.600000   NaN
# 00:00:01.700000   NaN
# 00:00:01.800000   NaN
# 00:00:01.900000   NaN
# 00:00:02          NaN
# 00:00:02.100000   NaN
# 00:00:02.200000   NaN
# 00:00:02.300000   NaN
# 00:00:02.400000   NaN
# 00:00:02.500000   NaN
# 00:00:02.600000   NaN
# 00:00:02.700000   NaN
# 00:00:02.800000   NaN
# 00:00:02.900000   NaN
# 00:00:03          NaN

# %%
# We only care about a subset of the RTTM's columns. We'll ignore the others.
# Also, for now, we only want to worry about the 'SPEECH' class.
ny_7759_short = ny_7759[['start', 'duration', 'class']][ny_7759['class']=='SPEECH'][0:10]
ny_7759_short.reset_index(drop=True, inplace=True)
ny_7759_short = ny_7759_short.round(0)

# %%
ny_7759_short
# Out:
#    start  duration   class
# 0    6.0       5.0  SPEECH
# 1   14.0       3.0  SPEECH
# 2   18.0       0.0  SPEECH
# 3   19.0       0.0  SPEECH
# 4   21.0       4.0  SPEECH
# 5   25.0      39.0  SPEECH
# 6   64.0       6.0  SPEECH
# 7   70.0      15.0  SPEECH
# 8   85.0       2.0  SPEECH
# 9   87.0      25.0  SPEECH

# %%
def build_second_indexed_df(input_df, label_list=[], verbose=True):
    """ Given an RTTM-generated DataFrame, generate a pivoted DF
        containing all of the labels of interest, one-hot encoded
    """
    
    max_seconds_needed = get_latest_timestamp_needed(input_df)
    if verbose:
        print(f'max_seconds_needed is of type {type(max_seconds_needed)} and equal to {max_seconds_needed}')
    outer_df = build_second_range(
                0,
                max_seconds_needed,
                np.nan,
                'base',
                verbose=True)
    
    if verbose:
        print(f'The outer_df frame will contain {len(outer_df)} records.')
    
    # Loop through labels, subsetting the original DF so
    # we can merge it back into the main outer DF
    for label in label_list:
        print(f'Processing label: {label}\n')

        if label not in input_df['class'].unique():
            print(f'Label {label} not found in this dataset')
            label_base_df = pd.DataFrame(columns=[label])
            continue
        
        # Gotta avoid errors from accidentally manipulating original DFs
        temp_df = copy.deepcopy(input_df)

        # Generate a temp_df that contains only records for the label of interest
        temp_df = input_df[['start','duration','class']][input_df['class']==label]

        if verbose:
            print(f'The temp_df subset for label {label} contains {len(temp_df)} rows')
            print(temp_df.head(5))
        
        # The subsetted DF retains the original index unless you reset it
        temp_df.reset_index(drop=True, inplace=True)

        if verbose:
            print(f'The temp_df frame is as follows:\n{temp_df}')

        # Creating the base DF for this label - ranges from 0 to the earliest record
        label_base_df = build_second_range(0, temp_df['start'].min(),
                                     np.nan, label, verbose=verbose)
        if verbose:
            # The head() will always be the same, so we need to look at the tail() to verify
            print(f'\n>>> The last few rows of the label_base_df for label {label} are:\n{label_base_df.tail()}')
            print(f"\n>>> Base DF size for label {label}: {len(temp_df)}\n")

        for i in range(1, len(temp_df)):
            label_base_df = label_base_df.append(
                build_second_range(
                    temp_df.loc[i]['start'],
                    temp_df.loc[i]['duration'],
                    str(label), str(label),
                    verbose=verbose
                ))

            if verbose:
                print(f'\n>>> Base DF size after {i} rounds: {len(label_base_df)}')
                print(f'\n>>> The head:\n{label_base_df.head(10)}\n>>> The tail:\n{label_base_df.tail(10)}')
                print(f'\n>>> A few of its contents:\n{label_base_df[~label_base_df[label].isna()].head(5)}')

        # Creating a placeholder for the update call
        outer_df[label] = np.nan
        
        # When attempting the update method:
        print(f'Attempting update with DF from label {label}')
        outer_df.update(label_base_df, overwrite=True)
        
        if verbose:
            try:
                print(outer_df[~outer_df[label].isna()].head())
            except:
                print(outer_df)
            
        # When attempting the merge method:
#         outer_df = pd.merge(left=outer_df, left_index=True,
#                             right=label_base_df, right_index=True,
#                             how='inner', suffixes=('_base',''),
#                             indicator=True, validate='1:1')
#         if verbose:
#             print(outer_df[~outer_df[f'{label}_y'].isna()].head(5))

    return outer_df

# %%
tester = df_from_rttm('./TestData/eNY-7759.rttm').round(1)
tester[['start', 'duration']] = tester[['start', 'duration']]*1000
labels = ['MAL', 'CHI', 'KCHI', 'FEM', 'SPEECH']
result = build_second_indexed_df(tester, label_list=labels, verbose=True)
# Out:
# max_seconds_needed is of type <class 'numpy.float64'> and equal to 239100.0
# Low end: 0 days 00:00:00
# Duration: 0 days 00:03:59.100000
#
#                  base
# seconds
# 00:00:00          NaN
# 00:00:00.100000   NaN
# 00:00:00.200000   NaN
# The outer_df frame will contain 2392 records.
# Processing label: MAL
#
# The temp_df subset for label MAL contains 26 rows
#       start  duration class
# 3    9600.0     400.0   MAL
# 5   12600.0    1800.0   MAL
# 8   18400.0    1600.0   MAL
# 15  25400.0     100.0   MAL
# 16  25800.0     200.0   MAL
# The temp_df frame is as follows:
#        start  duration class
# 0     9600.0     400.0   MAL
# 1    12600.0    1800.0   MAL
# 2    18400.0    1600.0   MAL
# 3    25400.0     100.0   MAL
# 4    25800.0     200.0   MAL
# 5    56000.0    2700.0   MAL
# 6    59500.0    1600.0   MAL
# 7    72400.0     400.0   MAL
# 8    75000.0    2200.0   MAL
# 9    79300.0     600.0   MAL
# 10  101000.0    1000.0   MAL
# 11  102100.0     100.0   MAL
# 12  106800.0     200.0   MAL
# 13  121000.0     800.0   MAL
# 14  123300.0    1800.0   MAL
# 15  128500.0     200.0   MAL
# 16  138600.0    1000.0   MAL
# 17  139700.0     100.0   MAL
# 18  205400.0     400.0   MAL
# 19  206700.0     100.0   MAL
# 20  207000.0     200.0   MAL
# 21  210000.0     900.0   MAL
# 22  211000.0    1300.0   MAL
# 23  225100.0     200.0   MAL
# 24  238300.0     100.0   MAL
# 25  238600.0     100.0   MAL
# Low end: 0 days 00:00:00
# Duration: 0 days 00:00:09.600000
#
#                  MAL
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
#
# >>> The last few rows of the label_base_df for label MAL are:
#                  MAL
# seconds
# 00:00:09.200000  NaN
# 00:00:09.300000  NaN
# 00:00:09.400000  NaN
# 00:00:09.500000  NaN
# 00:00:09.600000  NaN
#
# >>> Base DF size for label MAL: 26
#
# Low end: 0 days 00:00:12.600000
# Duration: 0 days 00:00:01.800000
#
#                  MAL
# seconds
# 00:00:12.600000  MAL
# 00:00:12.700000  MAL
# 00:00:12.800000  MAL
#
# >>> Base DF size after 1 rounds: 116
#
# >>> The head:
#                  MAL
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  MAL
# seconds
# 00:00:13.500000  MAL
# 00:00:13.600000  MAL
# 00:00:13.700000  MAL
# 00:00:13.800000  MAL
# 00:00:13.900000  MAL
# 00:00:14         MAL
# 00:00:14.100000  MAL
# 00:00:14.200000  MAL
# 00:00:14.300000  MAL
# 00:00:14.400000  MAL
#
# >>> A few of its contents:
#                  MAL
# seconds
# 00:00:12.600000  MAL
# 00:00:12.700000  MAL
# 00:00:12.800000  MAL
# 00:00:12.900000  MAL
# 00:00:13         MAL
# Low end: 0 days 00:00:18.400000
# Duration: 0 days 00:00:01.600000
#
#                  MAL
# seconds
# 00:00:18.400000  MAL
# 00:00:18.500000  MAL
# 00:00:18.600000  MAL
#
# >>> Base DF size after 2 rounds: 133
#
# >>> The head:
#                  MAL
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  MAL
# seconds
# 00:00:19.100000  MAL
# 00:00:19.200000  MAL
# 00:00:19.300000  MAL
# 00:00:19.400000  MAL
# 00:00:19.500000  MAL
# 00:00:19.600000  MAL
# 00:00:19.700000  MAL
# 00:00:19.800000  MAL
# 00:00:19.900000  MAL
# 00:00:20         MAL
#
# >>> A few of its contents:
#                  MAL
# seconds
# 00:00:12.600000  MAL
# 00:00:12.700000  MAL
# 00:00:12.800000  MAL
# 00:00:12.900000  MAL
# 00:00:13         MAL
# Low end: 0 days 00:00:25.400000
# Duration: 0 days 00:00:00.100000
#
#                  MAL
# seconds
# 00:00:25.400000  MAL
# 00:00:25.500000  MAL
#
# >>> Base DF size after 3 rounds: 135
#
# >>> The head:
#                  MAL
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  MAL
# seconds
# 00
  MAL
#
# >>> A few of its contents:
#                  MAL
# seconds
# 00:00:12.600000  MAL
# 00:00:12.700000  MAL
# 00:00:12.800000  MAL
# 00:00:12.900000  MAL
# 00:00:13         MAL
# Low end: 0 days 00:03:31
# Duration: 0 days 00:00:01.300000
#
#                  MAL
# seconds
# 00:03:31         MAL
# 00:03:31.100000  MAL
# 00:03:31.200000  MAL
#
# >>> Base DF size after 22 rounds: 312
#
# >>> The head:
#                  MAL
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  MAL
# seconds
# 00:03:31.400000  MAL
# 00:03:31.500000  MAL
# 00:03:31.600000  MAL
# 00:03:31.700000  MAL
# 00:03:31.800000  MAL
# 00:03:31.900000  MAL
# 00:03:32         MAL
# 00:03:32.100000  MAL
# 00:03:32.200000  MAL
# 00:03:32.300000  MAL
#
# >>> A few of its contents:
#                  MAL
# seconds
# 00:00:12.600000  MAL
# 00:00:12.700000  MAL
# 00:00:12.800000  MAL
# 00:00:12.900000  MAL
# 00:00:13         MAL
# Low end: 0 days 00:03:45.100000
# Duration: 0 days 00:00:00.200000
#
#                  MAL
# seconds
# 00:03:45.100000  MAL
# 00:03:45.200000  MAL
# 00:03:45.300000  MAL
#
# >>> Base DF size after 23 rounds: 315
#
# >>> The head:
#                  MAL
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  MAL
# seconds
# 00:03:31.700000  MAL
# 00:03:31.800000  MAL
# 00:03:31.900000  MAL
# 00:03:32         MAL
# 00:03:32.100000  MAL
# 00:03:32.200000  MAL
# 00:03:32.300000  MAL
# 00:03:45.100000  MAL
# 00:03:45.200000  MAL
# 00:03:45.300000  MAL
#
# >>> A few of its contents:
#                  MAL
# seconds
# 00:00:12.600000  MAL
# 00:00:12.700000  MAL
# 00:00:12.800000  MAL
# 00:00:12.900000  MAL
# 00:00:13         MAL
# Low end: 0 days 00:03:58.300000
# Duration: 0 days 00:00:00.100000
#
#                  MAL
# seconds
# 00:03:58.300000  MAL
# 00:03:58.400000  MAL
#
# >>> Base DF size after 24 rounds: 317
#
# >>> The head:
#                  MAL
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  MAL
# seconds
# 00:03:31.900000  MAL
# 00:03:32         MAL
# 00:03:32.100000  MAL
# 00:03:32.200000  MAL
# 00:03:32.300000  MAL
# 00:03:45.100000  MAL
# 00:03:45.200000  MAL
# 00:03:45.300000  MAL
# 00:03:58.300000  MAL
# 00:03:58.400000  MAL
#
# >>> A few of its contents:
#                  MAL
# seconds
# 00:00:12.600000  MAL
# 00:00:12.700000  MAL
# 00:00:12.800000  MAL
# 00:00:12.900000  MAL
# 00:00:13         MAL
# Low end: 0 days 00:03:58.600000
# Duration: 0 days 00:00:00.100000
#
#                  MAL
# seconds
# 00:03:58.600000  MAL
# 00:03:58.700000  MAL
#
# >>> Base DF size after 25 rounds: 319
#
# >>> The head:
#                  MAL
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  MAL
# seconds
# 00:03:32.100000  MAL
# 00:03:32.200000  MAL
# 00:03:32.300000  MAL
# 00:03:45.100000  MAL
# 00:03:45.200000  MAL
# 00:03:45.300000  MAL
# 00:03:58.300000  MAL
# 00:03:58.400000  MAL
# 00:03:58.600000  MAL
# 00:03:58.700000  MAL
#
# >>> A few of its contents:
#                  MAL
# seconds
# 00:00:12.600000  MAL
# 00:00:12.700000  MAL
# 00:00:12.800000  MAL
# 00:00:12.900000  MAL
# 00:00:13         MAL
# Attempting update with DF from label MAL
#                  base  MAL
# seconds
# 00:00:12.600000   NaN  MAL
# 00:00:12.700000   NaN  MAL
# 00:00:12.800000   NaN  MAL
# 00:00:12.900000   NaN  MAL
# 00:00:13          NaN  MAL
# Processing label: CHI
#
# The temp_df subset for label CHI contains 24 rows
#       start  duration class
# 19  33000.0     400.0   CHI
# 22  37100.0     300.0   CHI
# 28  41000.0     200.0   CHI
# 29  42400.0     100.0   CHI
# 30  43000.0     400.0   CHI
# The temp_df frame is as follows:
#        start  duration class
# 0    33000.0     400.0   CHI
# 1    37100.0     300.0   CHI
# 2    41000.0     200.0   CHI
# 3    42400.0     100.0   CHI
# 4    43000.0     400.0   CHI
# 5    45300.0    1800.0   CHI
# 6    48000.0     300.0   CHI
# 7    51100.0     400.0   CHI
# 8    54000.0     400.0   CHI
# 9    80000.0     100.0   CHI
# 10   80400.0    3100.0   CHI
# 11   98000.0     400.0   CHI
# 12  113000.0     200.0   CHI
# 13  114200.0     200.0   CHI
# 14  126000.0     100.0   CHI
# 15  134000.0     100.0   CHI
# 16  134500.0     500.0   CHI
# 17  159600.0     900.0   CHI
# 18  170700.0     700.0   CHI
# 19  203400.0    1500.0   CHI
# 20  220300.0    1200.0   CHI
# 21  223400.0    5400.0   CHI
# 22  234300.0    1000.0   CHI
# 23  239000.0     100.0   CHI
# Low end: 0 days 00:00:00
# Duration: 0 days 00:00:33
#
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
#
# >>> The last few rows of the label_base_df for label CHI are:
#                  CHI
# seconds
# 00:00:32.600000  NaN
# 00:00:32.700000  NaN
# 00:00:32.800000  NaN
# 00:00:32.900000  NaN
# 00:00:33         NaN
#
# >>> Base DF size for label CHI: 24
#
# Low end: 0 days 00:00:37.100000
# Duration: 0 days 00:00:00.300000
#
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
#
# >>> Base DF size after 1 rounds: 335
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:00:32.500000  NaN
# 00:00:32.600000  NaN
# 00:00:32.700000  NaN
# 00:00:32.800000  NaN
# 00:00:32.900000  NaN
# 00:00:33         NaN
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# Low end: 0 days 00:00:41
# Duration: 0 days 00:00:00.200000
#
#                  CHI
# seconds
# 00:00:41         CHI
# 00:00:41.100000  CHI
# 00:00:41.200000  CHI
#
# >>> Base DF size after 2 rounds: 338
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:00:32.800000  NaN
# 00:00:32.900000  NaN
# 00:00:33         NaN
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# 00:00:41.100000  CHI
# 00:00:41.200000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:00:42.400000
# Duration: 0 days 00:00:00.100000
#
#                  CHI
# seconds
# 00:00:42.400000  CHI
# 00:00:42.500000  CHI
#
# >>> Base DF size after 3 rounds: 340
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:00:33         NaN
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# 00:00:41.100000  CHI
# 00:00:41.200000  CHI
# 00:00:42.400000  CHI
# 00:00:42.500000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:00:43
# Duration: 0 days 00:00:00.400000
#
#                  CHI
# seconds
# 00:00:43         CHI
# 00:00:43.100000  CHI
# 00:00:43.200000  CHI
#
# >>> Base DF size after 4 rounds: 345
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:00:41         CHI
# 00:00:41.100000  CHI
# 00:00:41.200000  CHI
# 00:00:42.400000  CHI
# 00:00:42.500000  CHI
# 00:00:43         CHI
# 00:00:43.100000  CHI
# 00:00:43.200000  CHI
# 00:00:43.300000  CHI
# 00:00:43.400000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:00:45.300000
# Duration: 0 days 00:00:01.800000
#
#                  CHI
# seconds
# 00:00:45.300000  CHI
# 00:00:45.400000  CHI
# 00:00:45.500000  CHI
#
# >>> Base DF size after 5 rounds: 364
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:00:46.200000  CHI
# 00:00:46.300000  CHI
# 00:00:46.400000  CHI
# 00:00:46.500000  CHI
# 00:00:46.600000  CHI
# 00:00:46.700000  CHI
# 00:00:46.800000  CHI
# 00:00:46.900000  CHI
# 00:00:47         CHI
# 00:00:47.100000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:00:48
# Duration: 0 days 00:00:00.300000
#
#                  CHI
# seconds
# 00:00:48         CHI
# 00:00:48.100000  CHI
# 00:00:48.200000  CHI
#
# >>> Base DF size after 6 rounds: 368
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:00:46.600000  CHI
# 00:00:46.700000  CHI
# 00:00:46.800000  CHI
# 00:00:46.900000  CHI
# 00:00:47         CHI
# 00:00:47.100000  CHI
# 00:00:48         CHI
# 00:00:48.100000  CHI
# 00:00:48.200000  CHI
# 00:00:48.300000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:00:51.100000
# Duration: 0 days 00:00:00.400000
#
#                  CHI
# seconds
# 00:00:51.100000  CHI
# 00:00:51.200000  CHI
# 00:00:51.300000  CHI
#
# >>> Base DF size after 7 rounds: 373
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:00:47.100000  CHI
# 00:00:48         CHI
# 00:00:48.100000  CHI
# 00:00:48.200000  CHI
# 00:00:48.300000  CHI
# 00:00:51.100000  CHI
# 00:00:51.200000  CHI
# 00:00:51.300000  CHI
# 00:00:51.400000  CHI
# 00:00:51.500000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:00:54
# Duration: 0 days 00:00:00.400000
#
#                  CHI
# seconds
# 00:00:54         CHI
# 00:00:54.100000  CHI
# 00:00:54.200000  CHI
#
# >>> Base DF size after 8 rounds: 378
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:00:51.100000  CHI
# 00:00:51.200000  CHI
# 00:00:51.300000  CHI
# 00:00:51.400000  CHI
# 00:00:51.500000  CHI
# 00:00:54         CHI
# 00:00:54.100000  CHI
# 00:00:54.200000  CHI
# 00:00:54.300000  CHI
# 00:00:54.400000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:01:20
# Duration: 0 days 00:00:00.100000
#
#                  CHI
# seconds
# 00:01:20         CHI
# 00:01:20.100000  CHI
#
# >>> Base DF size after 9 rounds: 380
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:00:51.300000  CHI
# 00:00:51.400000  CHI
# 00:00:51.500000  CHI
# 00:00:54         CHI
# 00:00:54.100000  CHI
# 00:00:54.200000  CHI
# 00:00:54.300000  CHI
# 00:00:54.400000  CHI
# 00:01:20         CHI
# 00:01:20.100000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:01:20.400000
# Duration: 0 days 00:00:03.100000
#
#                  CHI
# seconds
# 00:01:20.400000  CHI
# 00:01:20.500000  CHI
# 00:01:20.600000  CHI
#
# >>> Base DF size after 10 rounds: 412
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:01:22.600000  CHI
# 00:01:22.700000  CHI
# 00:01:22.800000  CHI
# 00:01:22.900000  CHI
# 00:01:23         CHI
# 00:01:23.100000  CHI
# 00:01:23.200000  CHI
# 00:01:23.300000  CHI
# 00:01:23.400000  CHI
# 00:01:23.500000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:01:38
# Duration: 0 days 00:00:00.400000
#
#                  CHI
# seconds
# 00:01:38         CHI
# 00:01:38.100000  CHI
# 00:01:38.200000  CHI
#
# >>> Base DF size after 11 rounds: 417
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:01:23.100000  CHI
# 00:01:23.200000  CHI
# 00:01:23.300000  CHI
# 00:01:23.400000  CHI
# 00:01:23.500000  CHI
# 00:01:38         CHI
# 00:01:38.100000  CHI
# 00:01:38.200000  CHI
# 00:01:38.300000  CHI
# 00:01:38.400000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:01:53
# Duration: 0 days 00:00:00.200000
#
#                  CHI
# seconds
# 00:01:53         CHI
# 00:01:53.100000  CHI
# 00:01:53.200000  CHI
#
# >>> Base DF size after 12 rounds: 420
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:01:23.400000  CHI
# 00:01:23.500000  CHI
# 00:01:38         CHI
# 00:01:38.100000  CHI
# 00:01:38.200000  CHI
# 00:01:38.300000  CHI
# 00:01:38.400000  CHI
# 00:01:53         CHI
# 00:01:53.100000  CHI
# 00:01:53.200000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:01:54.200000
# Duration: 0 days 00:00:00.200000
#
#                  CHI
# seconds
# 00:01:54.200000  CHI
# 00:01:54.300000  CHI
# 00:01:54.400000  CHI
#
# >>> Base DF size after 13 rounds: 423
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:01:38.100000  CHI
# 00:01:38.200000  CHI
# 00:01:38.300000  CHI
# 00:01:38.400000  CHI
# 00:01:53         CHI
# 00:01:53.100000  CHI
# 00:01:53.200000  CHI
# 00:01:54.200000  CHI
# 00:01:54.300000  CHI
# 00:01:54.400000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:02:06
# Duration: 0 days 00:00:00.100000
#
#                  CHI
# seconds
# 00:02:06         CHI
# 00:02:06.100000  CHI
#
# >>> Base DF size after 14 rounds: 425
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:01:38.300000  CHI
# 00:01:38.400000  CHI
# 00:01:53         CHI
# 00:01:53.100000  CHI
# 00:01:53.200000  CHI
# 00:01:54.200000  CHI
# 00:01:54.300000  CHI
# 00:01:54.400000  CHI
# 00:02:06         CHI
# 00:02:06.100000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:02:14
# Duration: 0 days 00:00:00.100000
#
#                  CHI
# seconds
# 00:02:14         CHI
# 00:02:14.100000  CHI
#
# >>> Base DF size after 15 rounds: 427
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:01:53         CHI
# 00:01:53.100000  CHI
# 00:01:53.200000  CHI
# 00:01:54.200000  CHI
# 00:01:54.300000  CHI
# 00:01:54.400000  CHI
# 00:02:06         CHI
# 00:02:06.100000  CHI
# 00:02:14         CHI
# 00:02:14.100000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:02:14.500000
# Duration: 0 days 00:00:00.500000
#
#                  CHI
# seconds
# 00:02:14.500000  CHI
# 00:02:14.600000  CHI
# 00:02:14.700000  CHI
#
# >>> Base DF size after 16 rounds: 433
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:02:06         CHI
# 00:02:06.100000  CHI
# 00:02:14         CHI
# 00:02:14.100000  CHI
# 00:02:14.500000  CHI
# 00:02:14.600000  CHI
# 00:02:14.700000  CHI
# 00:02:14.800000  CHI
# 00:02:14.900000  CHI
# 00:02:15         CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:02:39.600000
# Duration: 0 days 00:00:00.900000
#
#                  CHI
# seconds
# 00:02:39.600000  CHI
# 00:02:39.700000  CHI
# 00:02:39.800000  CHI
#
# >>> Base DF size after 17 rounds: 443
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:02:39.600000  CHI
# 00:02:39.700000  CHI
# 00:02:39.800000  CHI
# 00:02:39.900000  CHI
# 00:02:40         CHI
# 00:02:40.100000  CHI
# 00:02:40.200000  CHI
# 00:02:40.300000  CHI
# 00:02:40.400000  CHI
# 00:02:40.500000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:02:50.700000
# Duration: 0 days 00:00:00.700000
#
#                  CHI
# seconds
# 00:02:50.700000  CHI
# 00:02:50.800000  CHI
# 00:02:50.900000  CHI
#
# >>> Base DF size after 18 rounds: 451
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:02:40.400000  CHI
# 00:02:40.500000  CHI
# 00:02:50.700000  CHI
# 00:02:50.800000  CHI
# 00:02:50.900000  CHI
# 00:02:51         CHI
# 00:02:51.100000  CHI
# 00:02:51.200000  CHI
# 00:02:51.300000  CHI
# 00:02:51.400000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:03:23.400000
# Duration: 0 days 00:00:01.500000
#
#                  CHI
# seconds
# 00:03:23.400000  CHI
# 00:03:23.500000  CHI
# 00:03:23.600000  CHI
#
# >>> Base DF size after 19 rounds: 467
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:03:24         CHI
# 00:03:24.100000  CHI
# 00:03:24.200000  CHI
# 00:03:24.300000  CHI
# 00:03:24.400000  CHI
# 00:03:24.500000  CHI
# 00:03:24.600000  CHI
# 00:03:24.700000  CHI
# 00:03:24.800000  CHI
# 00:03:24.900000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:03:40.300000
# Duration: 0 days 00:00:01.200000
#
#                  CHI
# seconds
# 00:03:40.300000  CHI
# 00:03:40.400000  CHI
# 00:03:40.500000  CHI
#
# >>> Base DF size after 20 rounds: 480
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:03:40.600000  CHI
# 00:03:40.700000  CHI
# 00:03:40.800000  CHI
# 00:03:40.900000  CHI
# 00:03:41         CHI
# 00:03:41.100000  CHI
# 00:03:41.200000  CHI
# 00:03:41.300000  CHI
# 00:03:41.400000  CHI
# 00:03:41.500000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:03:43.400000
# Duration: 0 days 00:00:05.400000
#
#                  CHI
# seconds
# 00:03:43.400000  CHI
# 00:03:43.500000  CHI
# 00:03:43.600000  CHI
#
# >>> Base DF size after 21 rounds: 535
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:03:47.900000  CHI
# 00:03:48         CHI
# 00:03:48.100000  CHI
# 00:03:48.200000  CHI
# 00:03:48.300000  CHI
# 00:03:48.400000  CHI
# 00:03:48.500000  CHI
# 00:03:48.600000  CHI
# 00:03:48.700000  CHI
# 00:03:48.800000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:03:54.300000
# Duration: 0 days 00:00:01
#
#                  CHI
# seconds
# 00:03:54.300000  CHI
# 00:03:54.400000  CHI
# 00:03:54.500000  CHI
#
# >>> Base DF size after 22 rounds: 546
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:03:54.400000  CHI
# 00:03:54.500000  CHI
# 00:03:54.600000  CHI
# 00:03:54.700000  CHI
# 00:03:54.800000  CHI
# 00:03:54.900000  CHI
# 00:03:55         CHI
# 00:03:55.100000  CHI
# 00:03:55.200000  CHI
# 00:03:55.300000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Low end: 0 days 00:03:59
# Duration: 0 days 00:00:00.100000
#
#                  CHI
# seconds
# 00:03:59         CHI
# 00:03:59.100000  CHI
#
# >>> Base DF size after 23 rounds: 548
#
# >>> The head:
#                  CHI
# seconds
# 00:00:00         NaN
# 00:00:00.100000  NaN
# 00:00:00.200000  NaN
# 00:00:00.300000  NaN
# 00:00:00.400000  NaN
# 00:00:00.500000  NaN
# 00:00:00.600000  NaN
# 00:00:00.700000  NaN
# 00:00:00.800000  NaN
# 00:00:00.900000  NaN
# >>> The tail:
#                  CHI
# seconds
# 00:03:54.600000  CHI
# 00:03:54.700000  CHI
# 00:03:54.800000  CHI
# 00:03:54.900000  CHI
# 00:03:55         CHI
# 00:03:55.100000  CHI
# 00:03:55.200000  CHI
# 00:03:55.300000  CHI
# 00:03:59         CHI
# 00:03:59.100000  CHI
#
# >>> A few of its contents:
#                  CHI
# seconds
# 00:00:37.100000  CHI
# 00:00:37.200000  CHI
# 00:00:37.300000  CHI
# 00:00:37.400000  CHI
# 00:00:41         CHI
# Attempting update with DF from label CHI
#                  base  MAL  CHI
# seconds
# 00:00:37.100000   NaN  NaN  CHI
# 00:00:37.200000   NaN  NaN  CHI
# 00:00:37.300000   NaN  NaN  CHI
# 00:00:37.400000   NaN  NaN  CHI
# 00:00:41          NaN  NaN  CHI
# Processing label: KCHI
#
# The temp_df subset for label KCHI contains 26 rows
#       start  duration class
# 1    6200.0     800.0  KCHI
# 2    7800.0     100.0  KCHI
# 4   10700.0     200.0  KCHI
# 7   16700.0     300.0  KCHI
# 13  23500.0     500.0  KCHI
# The temp_df frame is as follows:
#        start  duration class
# 0     6200.0     800.0  KCHI
# 1     7800.0     100.0  KCHI
# 2    10700.0     200.0  KCHI
# 3    16700.0     300.0  KCHI
# 4    23500.0     500.0  KCHI
# 5    35000.0    1900.0  KCHI
# 6    37500.0    1500.0  KCHI
# 7    40000.0     200.0  KCHI
# 8    41000.0     500.0  KCHI
# 9    66800.0    1500.0  KCHI
# 10   87500.0    1500.0  KCHI
# 11  113000.0     500.0  KCHI
# 12  115200.0     300.0  KCHI
# ...
# 00:01:51.900000  SPEECH
# 00:01:52         SPEECH
# 00:01:52.100000  SPEECH
# 00:01:52.200000  SPEECH
# 00:01:52.300000  SPEECH
# 00:01:52.400000  SPEECH
# 00:01:52.500000  SPEECH
# 00:01:52.600000  SPEECH
#
# >>> A few of its contents:
#                  SPEECH
# seconds
# 00:00:14         SPEECH
# 00:00:14.100000  SPEECH
# 00:00:14.200000  SPEECH
# 00:00:14.300000  SPEECH
# 00:00:14.400000  SPEECH
# Low end: 0 days 00:01:53
# Duration: 0 days 00:00:09.800000
#
#                  SPEECH
# seconds
# 00:01:53         SPEECH
# 00:01:53.100000  SPEECH
# 00:01:53.200000  SPEECH
#
# >>> Base DF size after 10 rounds: 1100
#
# >>> The head:
#                 SPEECH
# seconds
# 00:00:00           NaN
# 00:00:00.100000    NaN
# 00:00:00.200000    NaN
# 00:00:00.300000    NaN
# 00:00:00.400000    NaN
# 00:00:00.500000    NaN
# 00:00:00.600000    NaN
# 00:00:00.700000    NaN
# 00:00:00.800000    NaN
# 00:00:00.900000    NaN
# >>> The tail:
#                  SPEECH
# seconds
# 00:02:01.900000  SPEECH
# 00:02:02         SPEECH
# 00:02:02.100000  SPEECH
# 00:02:02.200000  SPEECH
# 00:02:02.300000  SPEECH
# 00:02:02.400000  SPEECH
# 00:02:02.500000  SPEECH
# 00:02:02.600000  SPEECH
# 00:02:02.700000  SPEECH
# 00:02:02.800000  SPEECH
#
# >>> A few of its contents:
#                  SPEECH
# seconds
# 00:00:14         SPEECH
# 00:00:14.100000  SPEECH
# 00:00:14.200000  SPEECH
# 00:00:14.300000  SPEECH
# 00:00:14.400000  SPEECH
# Low end: 0 days 00:02:03.500000
# Duration: 0 days 00:00:01.500000
#
#                  SPEECH
# seconds
# 00:02:03.500000  SPEECH
# 00:02:03.600000  SPEECH
# 00:02:03.700000  SPEECH
#
# >>> Base DF size after 11 rounds: 1116
#
# >>> The head:
#                 SPEECH
# seconds
# 00:00:00           NaN
# 00:00:00.100000    NaN
# 00:00:00.200000    NaN
# 00:00:00.300000    NaN
# 00:00:00.400000    NaN
# 00:00:00.500000    NaN
# 00:00:00.600000    NaN
# 00:00:00.700000    NaN
# 00:00:00.800000    NaN
# 00:00:00.900000    NaN
# >>> The tail:
#                  SPEECH
# seconds
# 00:02:04.100000  SPEECH
# 00:02:04.200000  SPEECH
# 00:02:04.300000  SPEECH
# 00:02:04.400000  SPEECH
# 00:02:04.500000  SPEECH
# 00:02:04.600000  SPEECH
# 00:02:04.700000  SPEECH
# 00:02:04.800000  SPEECH
# 00:02:04.900000  SPEECH
# 00:02:05         SPEECH
#
# >>> A few of its contents:
#                  SPEECH
# seconds
# 00:00:14         SPEECH
# 00:00:14.100000  SPEECH
# 00:00:14.200000  SPEECH
# 00:00:14.300000  SPEECH
# 00:00:14.400000  SPEECH
# Low end: 0 days 00:02:05.300000
# Duration: 0 days 00:00:03.700000
#
#                  SPEECH
# seconds
# 00:02:05.300000  SPEECH
# 00:02:05.400000  SPEECH
# 00:02:05.500000  SPEECH
#
# >>> Base DF size after 12 rounds: 1154
#
# >>> The head:
#                 SPEECH
# seconds
# 00:00:00           NaN
# 00:00:00.100000    NaN
# 00:00:00.200000    NaN
# 00:00:00.300000    NaN
# 00:00:00.400000    NaN
# 00:00:00.500000    NaN
# 00:00:00.600000    NaN
# 00:00:00.700000    NaN
# 00:00:00.800000    NaN
# 00:00:00.900000    NaN
# >>> The tail:
#                  SPEECH
# seconds
# 00:02
  SPEECH
#
# >>> A few of its contents:
#                  SPEECH
# seconds
# 00:00:14         SPEECH
# 00:00:14.100000  SPEECH
# 00:00:14.200000  SPEECH
# 00:00:14.300000  SPEECH
# 00:00:14.400000  SPEECH
# Low end: 0 days 00:02:34.800000
# Duration: 0 days 00:00:13.800000
#
#                  SPEECH
# seconds
# 00:02:34.800000  SPEECH
# 00:02:34.900000  SPEECH
# 00:02:35         SPEECH
#
# >>> Base DF size after 18 rounds: 1517
#
# >>> The head:
#                 SPEECH
# seconds
# 00:00:00           NaN
# 00:00:00.100000    NaN
# 00:00:00.200000    NaN
# 00:00:00.300000    NaN
# 00:00:00.400000    NaN
# 00:00:00.500000    NaN
# 00:00:00.600000    NaN
# 00:00:00.700000    NaN
# 00:00:00.800000    NaN
# 00:00:00.900000    NaN
# >>> The tail:
#                  SPEECH
# seconds
# 00:02:47.700000  SPEECH
# 00:02:47.800000  SPEECH
# 00:02:47.900000  SPEECH
# 00:02:48         SPEECH
# 00:02:48.100000  SPEECH
# 00:02:48.200000  SPEECH
# 00:02:48.300000  SPEECH
# 00:02:48.400000  SPEECH
# 00:02:48.500000  SPEECH
# 00:02:48.600000  SPEECH
#
# >>> A few of its contents:
#                  SPEECH
# seconds
# 00:00:14         SPEECH
# 00:00:14.100000  SPEECH
# 00:00:14.200000  SPEECH
# 00:00:14.300000  SPEECH
# 00:00:14.400000  SPEECH
# Low end: 0 days 00:02:49.500000
# Duration: 0 days 00:00:04.800000
#
#                  SPEECH
# seconds
# 00:02:49.500000  SPEECH
# 00:02:49.600000  SPEECH
# 00:02:49.700000  SPEECH
#
# >>> Base DF size after 19 rounds: 1566
#
# >>> The head:
#                 SPEECH
# seconds
# 00:00:00           NaN
# 00:00:00.100000    NaN
# 00:00:00.200000    NaN
# 00:00:00.300000    NaN
# 00:00:00.400000    NaN
# 00:00:00.500000    NaN
# 00:00:00.600000    NaN
# 00:00:00.700000    NaN
# 00:00:00.800000    NaN
# 00:00:00.900000    NaN
# >>> The tail:
#                  SPEECH
# seconds
# 00:02:53.400000  SPEECH
# 00:02:53.500000  SPEECH
# 00:02:53.600000  SPEECH
# 00:02:53.700000  SPEECH
# 00:02:53.800000  SPEECH
# 00:02:53.900000  SPEECH
# 00:02:54         SPEECH
# 00:02:54.100000  SPEECH
# 00:02:54.200000  SPEECH
# 00:02:54.300000  SPEECH
#
# >>> A few of its contents:
#                  SPEECH
# seconds
# 00:00:14         SPEECH
# 00:00:14.100000  SPEECH
# 00:00:14.200000  SPEECH
# 00:00:14.300000  SPEECH
# 00:00:14.400000  SPEECH
# Low end: 0 days 00:02:55.200000
# Duration: 0 days 00:00:11.400000
#
#                  SPEECH
# seconds
# 00:02:55.200000  SPEECH
# 00:02:55.300000  SPEECH
# 00:02:55.400000  SPEECH
#
# >>> Base DF size after 20 rounds: 1681
#
# >>> The head:
#                 SPEECH
# seconds
# 00:00:00           NaN
# 00:00:00.100000    NaN
# 00:00:00.200000    NaN
# 00:00:00.300000    NaN
# 00:00:00.400000    NaN
# 00:00:00.500000    NaN
# 00:00:00.600000    NaN
# 00:00:00.700000    NaN
# 00:00:00.800000    NaN
# 00:00:00.900000    NaN
# >>> The tail:
#                  SPEECH
# seconds
# 00:03:05.700000  SPEECH
# 00:03:05.800000  SPEECH
# 00:03:05.900000  SPEECH
# 00:03:06         SPEECH
# 00:03:06.100000  SPEECH
# 00:03:06.200000  SPEECH
# 00:03:06.300000  SPEECH
# 00:03:06.400000  SPEECH
# 00:03:06.500000  SPEECH
# 00:03:06.600000  SPEECH
#
# >>> A few of its contents:
#                  SPEECH
# seconds
# 00:00:14         SPEECH
# 00:00:14.100000  SPEECH
# 00:00:14.200000  SPEECH
# 00:00:14.300000  SPEECH
# 00:00:14.400000  SPEECH
# Low end: 0 days 00:03:07
# Duration: 0 days 00:00:04.100000
#
#                  SPEECH
# seconds
# 00:03:07         SPEECH
# 00:03:07.100000  SPEECH
# 00:03:07.200000  SPEECH
#
# >>> Base DF size after 21 rounds: 1723
#
# >>> The head:
#                 SPEECH
# seconds
# 00:00:00           NaN
# 00:00:00.100000    NaN
# 00:00:00.200000    NaN
# 00:00:00.300000    NaN
# 00:00:00.400000    NaN
# 00:00:00.500000    NaN
# 00:00:00.600000    NaN
# 00:00:00.700000    NaN
# 00:00:00.800000    NaN
# 00:00:00.900000    NaN
# >>> The tail:
#                  SPEECH
# seconds
# 00:03:10.200000  SPEECH
# 00:03:10.300000  SPEECH
# 00:03:10.400000  SPEECH
# 00:03:10.500000  SPEECH
# 00:03:10.600000  SPEECH
# 00:03:10.700000  SPEECH
# 00:03:10.800000  SPEECH
# 00:03:10.900000  SPEECH
# 00:03:11         SPEECH
# 00:03:11.100000  SPEECH
#
# >>> A few of its contents:
#                  SPEECH
# seconds
# 00:00:14         SPEECH
# 00:00:14.100000  SPEECH
# 00:00:14.200000  SPEECH
# 00:00:14.300000  SPEECH
# 00:00:14.400000  SPEECH
# Low end: 0 days 00:03:11.200000
# Duration: 0 days 00:00:09.800000
#
#                  SPEECH
# seconds
# 00:03:11.200000  SPEECH
# 00:03:11.300000  SPEECH
# 00:03:11.400000  SPEECH
#
# >>> Base DF size after 22 rounds: 1822
#
# >>> The head:
#                 SPEECH
# seconds
# 00:00:00           NaN
# 00:00:00.100000    NaN
# 00:00:00.200000    NaN
# 00:00:00.300000    NaN
# 00:00:00.400000    NaN
# 00:00:00.500000    NaN
# 00:00:00.600000    NaN
# 00:00:00.700000    NaN
# 00:00:00.800000    NaN
# 00:00:00.900000    NaN
# >>> The tail:
#                  SPEECH
# seconds
# 00:03:20.100000  SPEECH
# 00:03:20.200000  SPEECH
# 00:03:20.300000  SPEECH
# 00:03:20.400000  SPEECH
# 00:03:20.500000  SPEECH
# 00:03:20.600000  SPEECH
# 00:03:20.700000  SPEECH
# 00:03:20.800000  SPEECH
# 00:03:20.900000  SPEECH
# 00:03:21         SPEECH
#
# >>> A few of its contents:
#                  SPEECH
# seconds
# 00:00:14         SPEECH
# 00:00:14.100000  SPEECH
# 00:00:14.200000  SPEECH
# 00:00:14.300000  SPEECH
# 00:00:14.400000  SPEECH
# Low end: 0 days 00:03:21.400000
# Duration: 0 days 00:00:33.900000
#
#                  SPEECH
# seconds
# 00:03:21.400000  SPEECH
# 00:03:21.500000  SPEECH
# 00:03:21.600000  SPEECH
#
# >>> Base DF size after 23 rounds: 2162
#
# >>> The head:
#                 SPEECH
# seconds
# 00:00:00           NaN
# 00:00:00.100000    NaN
# 00:00:00.200000    NaN
# 00:00:00.300000    NaN
# 00:00:00.400000    NaN
# 00:00:00.500000    NaN
# 00:00:00.600000    NaN
# 00:00:00.700000    NaN
# 00:00:00.800000    NaN
# 00:00:00.900000    NaN
# >>> The tail:
#                  SPEECH
# seconds
# 00:03:54.400000  SPEECH
# 00:03:54.500000  SPEECH
# 00:03:54.600000  SPEECH
# 00:03:54.700000  SPEECH
# 00:03:54.800000  SPEECH
# 00:03:54.900000  SPEECH
# 00:03:55         SPEECH
# 00:03:55.100000  SPEECH
# 00:03:55.200000  SPEECH
# 00:03:55.300000  SPEECH
#
# >>> A few of its contents:
#                  SPEECH
# seconds
# 00:00:14         SPEECH
# 00:00:14.100000  SPEECH
# 00:00:14.200000  SPEECH
# 00:00:14.300000  SPEECH
# 00:00:14.400000  SPEECH
# Low end: 0 days 00:03:55.500000
# Duration: 0 days 00:00:04.200000
#
#                  SPEECH
# seconds
# 00:03:55.500000  SPEECH
# 00:03:55.600000  SPEECH
# 00:03:55.700000  SPEECH
#
# >>> Base DF size after 24 rounds: 2205
#
# >>> The head:
#                 SPEECH
# seconds
# 00:00:00           NaN
# 00:00:00.100000    NaN
# 00:00:00.200000    NaN
# 00:00:00.300000    NaN
# 00:00:00.400000    NaN
# 00:00:00.500000    NaN
# 00:00:00.600000    NaN
# 00:00:00.700000    NaN
# 00:00:00.800000    NaN
# 00:00:00.900000    NaN
# >>> The tail:
#                  SPEECH
# seconds
# 00:03:58.800000  SPEECH
# 00:03:58.900000  SPEECH
# 00:03:59         SPEECH
# 00:03:59.100000  SPEECH
# 00:03:59.200000  SPEECH
# 00:03:59.300000  SPEECH
# 00:03:59.400000  SPEECH
# 00:03:59.500000  SPEECH
# 00:03:59.600000  SPEECH
# 00:03:59.700000  SPEECH
#
# >>> A few of its contents:
#                  SPEECH
# seconds
# 00:00:14         SPEECH
# 00:00:14.100000  SPEECH
# 00:00:14.200000  SPEECH
# 00:00:14.300000  SPEECH
# 00:00:14.400000  SPEECH
# Attempting update with DF from label SPEECH
#                  base  MAL  CHI KCHI  FEM  SPEECH
# seconds
# 00:00:14          NaN  MAL  NaN  NaN  NaN  SPEECH
# 00:00:14.100000   NaN  MAL  NaN  NaN  NaN  SPEECH
# 00:00:14.200000   NaN  MAL  NaN  NaN  NaN  SPEECH
# 00:00:14.300000   NaN  MAL  NaN  NaN  NaN  SPEECH
# 00:00:14.400000   NaN  MAL  NaN  NaN  NaN  SPEECH

# %%
result.loc['00:03:30.000':'00:03:40.000']
# Out:
#                  base  MAL  CHI KCHI  FEM  SPEECH
# seconds
# 00:03:30          NaN  MAL  NaN  NaN  FEM  SPEECH
# 00:03:30.100000   NaN  MAL  NaN  NaN  FEM  SPEECH
# 00:03:30.200000   NaN  MAL  NaN  NaN  FEM  SPEECH
# 00:03:30.300000   NaN  MAL  NaN  NaN  FEM  SPEECH
# 00:03:30.400000   NaN  MAL  NaN  NaN  FEM  SPEECH
# ...               ...  ...  ...  ...  ...     ...
# 00:03:40.500000   NaN  NaN  CHI  NaN  FEM  SPEECH
# 00:03:40.600000   NaN  NaN  CHI  NaN  FEM  SPEECH
# 00:03:40.700000   NaN  NaN  CHI  NaN  FEM  SPEECH
# 00:03:40.800000   NaN  NaN  CHI  NaN  FEM  SPEECH
# 00:03:40.900000   NaN  NaN  CHI  NaN  FEM  SPEECH
#
# [110 rows x 6 columns]

# %%
for col in result.columns:
    print(f""" This DataFrameresult[col].describe()

# %%
result.shape
# Out:
# (2392, 6)

# %%
result.to_csv('./TestData/eNY-7759.csv')
